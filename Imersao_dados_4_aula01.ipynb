# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosjorgeff/marcosjorgeff/blob/Master/Imersao_dados_4_aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cara um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados_media=dados.drop(["Cidade","Rua","Quartos","Banheiros","Vagas","Valor"],axis =1)#Media Metragem dos Bairros

# %%
media_Metragem=dados_media.groupby(["Bairro"]).mean("Metragem")

# %%
print(media_Metragem)
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988
# ...                       ...
# Vila Água Funda    152.200000
# Água Branca        191.000000
# Água Fria          165.416667
# Água Funda         139.000000
# Água Rasa          340.250000
#
# [701 rows x 1 columns]

# %%
gf = media_Metragem.head(10)
gf.plot.barh()

# %%
valida_media =( dados["Bairro"] == "Aclimação") #Validação da média e seleção de Bairro 1

# %%
valida_media_1= dados[valida_media]

# %%
valida_media_2= valida_media_1.Metragem.mean()
valida_media_2
# Out:
# 253.0568181818182

# %%
filtro = ["Alto da Boa Vista"] # Seleção dados 2

# %%
validacao_filtro = dados[dados.Bairro.isin(filtro)]

# %%
validacao_filtro
# Out:
#                           Rua             Bairro     Cidade  Metragem  \
# 65            Rua da Paz, 89   Alto da Boa Vista  São Paulo       386
# 143   Rua Américo Brasiliense  Alto da Boa Vista  São Paulo       340
# 339   Rua Américo Brasiliense  Alto da Boa Vista  São Paulo       350
# 3426               Rua da Paz  Alto da Boa Vista  São Paulo       315
# 4123  Rua Américo Brasiliense  Alto da Boa Vista  São Paulo       370
# 5310                      NaN  Alto da Boa Vista  São Paulo       595
# 6234               Rua da Paz  Alto da Boa Vista  São Paulo       595
# 8145               Rua da Paz  Alto da Boa Vista  São Paulo       400
#
#       Quartos  Banheiros  Vagas         Valor
# 65          4          4      5  R$ 1.680.000
# 143         4          6      7  R$ 2.200.000
# 339         4          6      4  R$ 2.200.000
# 3426        4          6      4  R$ 2.350.000
# 4123        4          3      3  R$ 2.750.000
# 5310        4          5      4  R$ 3.000.000
# ...

# %%
dados.describe()# Estatisticas dos dados
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
dados_valor=dados.drop(["Cidade","Rua","Quartos","Banheiros","Vagas","Valor"],axis =1)#10 imoveis com mais metragem

# %%
dados_valor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Bairro    9996 non-null   object
#  1   Metragem  10008 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 156.5+ KB

# %%
or_valor = dados_valor.sort_values(by=['Metragem'],
                         ignore_index=True,
                         ascending=False)

# %%
or_valor.head(10)
# Out:
#              Bairro  Metragem
# 0    Jardim Guedala    750000
# 1     Sítio Represa     37000
# 2  Jardim da Glória     35677
# 3       Santo Amaro      7126
# 4      Vila Castelo      2850
# 5          Pacaembu      2505
# 6          Pacaembu      2505
# 7          Pacaembu      2500
# 8    Retiro Morumbi      2200
# 9    Retiro Morumbi      2200

# %%
rua_null = dados["Rua"].isnull() # Bairros sem Rua
Bairro_sem_rua = dados[rua_null]

# %%
Bairro_sem_rua
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor
# 3             2      4    R$ 685.000
# ...
